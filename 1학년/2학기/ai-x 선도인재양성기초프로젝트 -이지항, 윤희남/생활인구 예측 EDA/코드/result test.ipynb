# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
answer = pd.read_csv('distribute_final_raw2.csv', sep=',', index_col=0)
answer
# Out:
#         id       count
# 0        0  36815.2556
# 1        1  36505.0757
# 2        2  36266.6345
# 3        3  36069.5391
# 4        4  35994.9474
# ...    ...         ...
# 1411  1411  35436.3320
# 1412  1412  35790.8544
# 1413  1413  36044.2670
# 1414  1414  37191.1706
# 1415  1415  39840.8794
#
# [1416 rows x 2 columns]

# %%
catboost1 = pd.read_csv('dkdkdsfksljlkThrTry_Catboost1.csv', sep=',', index_col=0)
catboost1
# Out:
#              count
# id
# 0     38068.254501
# 1     38179.278968
# 2     38090.110759
# 3     38098.269442
# 4     38098.573730
# ...            ...
# 1411  36736.179124
# 1412  36736.179124
# 1413  36753.754448
# 1414  36850.771437
# 1415  40353.884201
#
# [1416 rows x 1 columns]

# %%
ETR1 = pd.read_csv('SecondTry_ExtraTreesRegressor1.csv', sep=',', index_col=0)
ETR1
# Out:
#              count
# id
# 0     40032.460153
# 1     39554.744232
# 2     39193.715779
# 3     38859.477169
# 4     38890.236472
# ...            ...
# 1411  35537.158099
# 1412  35503.323784
# 1413  35448.663196
# 1414  35758.208182
# 1415  38688.864229
#
# [1416 rows x 1 columns]

# %%
LR1 = pd.read_csv('LinearRegression.csv', sep=',', index_col=0)
LR1
# Out:
#              count
# id
# 0     40345.997449
# 1     40180.351210
# 2     40036.833870
# 3     39974.244853
# 4     40049.198173
# ...            ...
# 1411  36234.407847
# 1412  36369.900811
# 1413  36781.538977
# 1414  37168.363039
# 1415  40051.482099
#
# [1416 rows x 1 columns]

# %%
jin = pd.read_csv('jinseok2222.csv', sep=',', index_col=0)
jin
# Out:
#              count
# id
# 0     39536.506268
# 1     39392.281392
# 2     39316.552838
# 3     39169.828717
# 4     39218.292854
# ...            ...
# 1411  36206.692915
# 1412  36276.816835
# 1413  37008.863418
# 1414  37122.910610
# 1415  39790.937683
#
# [1416 rows x 1 columns]

# %%
seok = pd.read_csv('jinseok11111.csv', sep=',', index_col=0)
seok
# Out:
#              count
# id
# 0     31629.205015
# 1     31513.825114
# 2     31453.242270
# 3     31335.862974
# 4     31374.634283
# ...            ...
# 1411  36206.692915
# 1412  36276.816835
# 1413  37008.863418
# 1414  37122.910610
# 1415  39790.937683
#
# [1416 rows x 1 columns]

# %%
seokd = pd.read_csv('jinseo.csv', sep=',', index_col=0)
seokd
# Out:
#              count
# id
# 0     38749.729794
# 1     38608.374992
# 2     38534.153437
# 3     38390.349126
# 4     38437.848826
# ...            ...
# 1411  36206.692915
# 1412  36276.816835
# 1413  37008.863418
# 1414  37122.910610
# 1415  39790.937683
#
# [1416 rows x 1 columns]

# %%
seokdd = pd.read_csv('jinse.csv', sep=',', index_col=0)
seokdd
# Out:
#              count
# id
# 0     39141.141206
# 1     38998.358578
# 2     38923.387310
# 3     38778.130430
# 4     38826.109925
# ...            ...
# 1411  36206.692915
# 1412  36276.816835
# 1413  37008.863418
# 1414  37122.910610
# 1415  39790.937683
#
# [1416 rows x 1 columns]

# %%
seokddd = pd.read_csv('jinseok19.csv', sep=',', index_col=0)
seokddd
# Out:
#             count
# id
# 0     37164.31589
# 1     37028.74451
# 2     36957.55967
# 3     36819.63899
# 4     36865.19528
# ...           ...
# 1411  36206.69291
# 1412  36276.81683
# 1413  37008.86342
# 1414  37122.91061
# 1415  39790.93768
#
# [1416 rows x 1 columns]

# %%
seokdddd = pd.read_csv('data newworld.csv', sep=',', index_col=0)
seokdddd
# Out:
#             count
# id
# 0     37164.31589
# 1     37028.74451
# 2     36957.55967
# 3     36819.63899
# 4     36865.19528
# ...           ...
# 1411  36206.69291
# 1412  36276.81683
# 1413  37008.86342
# 1414  37122.91061
# 1415  39790.93768
#
# [1416 rows x 1 columns]

# %%
plt.rc('font', family='Malgun Gothic')
sns.set(font="Malgun Gothic",#"NanumGothicCoding", 
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# %%
plt.figure(figsize=(15,4))
plt.plot(answer['count'], data = answer)
#plt.plot(catboost1['count'], data = catboost1)
#plt.plot(ETR1['count'], data = ETR1)
#plt.plot(LR1['count'], data = LR1)
#plt.plot(jin['count'], data = jin)
plt.plot(seokddd['count'], data = seokddd)
#plt.plot(seokdddd['count'], data = seokdddd)

# %%
result = pd.read_csv('result.csv', sep=',', index_col=0, encoding = 'cp949')
result
# Out:
#                   총생활인구수
# 2022/01/01 0:00    36885
# 2022/01/01 1:00    36575
# 2022/01/01 2:00    36337
# 2022/01/01 3:00    36139
# 2022/01/01 4:00    36065
# ...                  ...
# 2022/02/28 19:00   12577
# 2022/02/28 20:00   20381
# 2022/02/28 21:00   37370
# 2022/02/28 22:00   23549
# 2022/02/28 23:00   18246
#
# [1416 rows x 1 columns]

# %%
plt.figure(figsize=(14.16,4))
plt.plot(result['총생활인구수'], data = result)
