# %%
# !pip install pymongo
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 671.3/671.3 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 29.0 MB/s eta 0:00:00
# ...

# %%
import os
import sys
import pymongo
sys.path.append('/content/drive/MyDrive/Colab Notebooks')
import mylib as b


keyPath=os.path.join(os.getcwd(), '/content/drive/MyDrive/Colab Notebooks', 'key.properties')
key=b.getKey(keyPath)

# %%
print(key['mongo'])
# Out:
# jinseok02!

# %%
import pymongo

#mongodb+srv://rlawlstjr02:<password>!@cluster0.oyuzkx4.mongodb.net/?retryWrites=true&w=majority
uriLocal='mongodb://localhost:27017'  # 로컬에 연결하기 위한 uri
#uriCloud='mongodb+srv://user:pwd@cluster0.v0bapbt.mongodb.net/jsl?retryWrites=true&w=majority'   # 연결 DB까지 넣은 uri
uriCloud='mongodb+srv://rlawlstjr02:'+key['mongo']+'@cluster0.oyuzkx4.mongodb.net/?retryWrites=true&w=majority' # DB를 생략해도 된다.

Client = pymongo.MongoClient(uriCloud) # 로컬에서는 기본 포트를 사용하기 때문에 생략해도 된다 Client = pymo

# %%
print(uriCloud)
# Out:
# mongodb+srv://rlawlstjr02:jinseok02!@cluster0.oyuzkx4.mongodb.net/?retryWrites=true&w=majority

# %% [markdown]
# # 도로교통공단_사망교통사고정보서비스
# # 2023-09-22 ~ 2025-09-22
